# %%
import requests

import pandas as pd

import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
DF1=pd.read_csv('38100286.csv')

# %%
len(DF1['Primary heating system and type of energy'].unique())
# Out:
# 48

# %%
DF1.columns #Remove UOM, UOM_ID, SCALAR_FACTOR, SCALAR_ID, SYMBOL, TERMINATED, DECIMALS
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Primary heating system and type of energy',
#        'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE',
#        'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
BadCol1=['UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','SYMBOL','TERMINATED','DECIMALS']
BadCol1
DF1=DF1.drop(BadCol1, axis=1)
DF1=DF1.fillna(0)

# %%
DF1[(DF1['GEO']=='Newfoundland and Labrador')&(DF1['REF_DATE']==2017)]
# Out:
#       REF_DATE                        GEO        DGUID  \
# 4656      2017  Newfoundland and Labrador  2016A000210
# 4657      2017  Newfoundland and Labrador  2016A000210
# 4658      2017  Newfoundland and Labrador  2016A000210
# 4659      2017  Newfoundland and Labrador  2016A000210
# 4660      2017  Newfoundland and Labrador  2016A000210
# 4661      2017  Newfoundland and Labrador  2016A000210
# 4662      2017  Newfoundland and Labrador  2016A000210
# 4663      2017  Newfoundland and Labrador  2016A000210
# 4664      2017  Newfoundland and Labrador  2016A000210
# 4665      2017  Newfoundland and Labrador  2016A000210
# 4666      2017  Newfoundland and Labrador  2016A000210
# 4667      2017  Newfoundland and Labrador  2016A000210
# 4668      2017  Newfoundland and Labrador  2016A000210
# 4669      2017  Newfoundland and Labrador  2016A000210
# 4670      2017  Newfoundland and Labrador  2016A000210
# 4671      2017  Newfoundland and Labrador  2016A000210
# 4672      2017  Newfoundland and Labrador  2016A000210
# 4673      2017  Newfoundland and Labrador  2016A000210
# 4674      2017  Newfoundland and Labrador  2016A000210
# 4675      2017  Newfoundland and Labrador  2016A000210
# 4676      2017  Newfoundland and Labrador  2016A000210
# 4677      2017  Newfoundland and Labrador  2016A000210
# 4678      2017  Newfoundland and Labrador  2016A000210
# 4679      2017  Newfoundland and Labrador  2016A000210
# 4680      2017  Newfoundland and Labrador  2016A000210
# 4681      2017  Newfoundland and Labrador  2016A000210
# 4682      2017  Newfoundland and Labrador  2016A000210
# 4683      2017  Newfoundland and Labrador  2016A000210
# 4684      2017  Newfoundland and Labrador  2016A000210
# 4685      2017  Newfoundland and Labrador  2016A000210
# 4686      2017  Newfoundland and Labrador  2016A000210
# 4687      2017  Newfoundland and Labrador  2016A000210
# 4688      2017  Newfoundland and Labrador  2016A000210
# 4689      2017  Newfoundland and Labrador  2016A000210
# 4690      2017  Newfoundland and Labrador  2016A000210
# 4691      2017  Newfoundland and Labrador  2016A000210
# 4692      2017  Newfoundland and Labrador  2016A000210
# 4693      2017  Newfoundland and Labrador  2016A000210
# 4694      2017  Newfoundland and Labrador  2016A000210
# 4695      2017  Newfoundland and Labrador  2016A000210
# 4696      2017  Newfoundland and Labrador  2016A000210
# 4697      2017  Newfoundland and Labrador  2016A000210
# 4698      2017  Newfoundland and Labrador  2016A000210
# 4699      2017  Newfoundland and Labrador  2016A000210
# 4700      2017  Newfoundland and Labrador  2016A000210
# 4701      2017  Newfoundland and Labrador  2016A000210
# 4702      2017  Newfoundland and Labrador  2016A000210
# 4703      2017  Newfoundland and Labrador  2016A000210
#
#               Primary heating system and type of energy      VECTOR  \
# 4656                        All primary heating systems  v107791212
# 4657                                        Electricity  v107791213
# 4658                                        Natural gas  v107791214
# 4659                                                Oil  v107791215
# 4660                               Wood or wood pellets  v107791216
# 4661                      Wood (excluding wood pellets)  v107791217
# 4662                                       Wood pellets  v107791218
# 4663                                            Propane  v107791219
# 4664                                         Other fuel  v107791220
# 4665                                 Forced air furnace   v95637351
# 4666                        Electric forced air furnace   v95637352
# 4667                     Natural gas forced air furnace   v95637353
# 4668                             Oil forced air furnace   v95637354
# 4669            Wood or wood pellets forced air furnace   v95637355
# 4670   Wood (excluding wood pellets) forced air furnace   v95637356
# 4671                    Wood pellets forced air furnace   v95637357
# 4672                         Propane forced air furnace   v95637358
# 4673                      Other fuel forced air furnace   v95637359
# 4674                         Electric baseboard heaters   v95637360
# 4675                                      Heating stove   v95637361
# 4676                             Electric heating stove   v95637362
# 4677                          Natural gas heating stove   v95637363
# 4678                                  Oil heating stove   v95637364
# 4679                                 Wood heating stove   v95637365
# 4680        Wood (excluding wood pellets) heating stove   v95637366
# 4681                         Wood pellets heating stove   v95637367
# 4682                              Propane heating stove   v95637368
# 4683                           Other fuel heating stove   v95637369
# 4684           Boiler with hot water or steam radiators   v95637370
# 4685  Electric boiler with hot water or steam radiators   v95637371
# 4686  Natural gas boiler with hot water or steam rad...   v95637372
# 4687       Oil boiler with hot water or steam radiators   v95637373
# 4688      Wood boiler with hot water or steam radiators   v95637374
# 4689  Wood (excluding wood pellets) boiler with hot ...   v95637375
# 4690  Wood pellets boiler with hot water or steam ra...   v95637376
# 4691   Propane boiler with hot water or steam radiators   v95637377
# 4692  Other fuel boiler with hot water or steam radi...   v95637378
# 4693                           Electric radiant heating   v95637379
# 4694                                          Heat pump   v95637380
# 4695                       Other type of heating system   v95637381
# 4696                      Other electric heating system   v95637382
# 4697                   Other natural gas heating system   v95637383
# 4698                           Other oil heating system   v95637384
# 4699                          Other wood heating system   v95637385
# 4700  Other wood (excluding wood pellets) heating sy...   v95637386
# 4701                  Other wood pellets heating system   v95637387
# 4702                       Other propane heating system   v95637388
# 4703                          Other fuel heating system   v95637389
#
#       COORDINATE  VALUE STATUS
# 4656        2.40   92.0      0
# 4657        2.41   71.0      0
# 4658        2.42    0.0      F
# 4659        2.43   15.0      0
# 4660        2.44    9.0      E
# 4661        2.45    9.0      E
# 4662        2.46    0.0      F
# 4663        2.47    0.0      F
# 4664        2.48    0.0      F
# 4665        2.10   17.0      0
# 4666        2.20    0.0      F
# 4667        2.30    0.0      F
# 4668        2.40   71.0      0
# 4669        2.50   25.0      E
# 4670        2.60   25.0      E
# 4671        2.70    0.0      F
# 4672        2.80    0.0      F
# 4673        2.90    0.0      F
# 4674        2.10   65.0      0
# 4675        2.11    4.0      E
# 4676        2.12    0.0      F
# 4677        2.13    0.0      F
# 4678        2.14    0.0      F
# 4679        2.15   95.0      0
# 4680        2.16   95.0      0
# 4681        2.17    0.0      F
# 4682        2.18    0.0      F
# 4683        2.19    0.0      F
# 4684        2.20    4.0      E
# 4685        2.21    0.0      F
# 4686        2.22    0.0      F
# 4687        2.23   67.0      E
# 4688        2.24    0.0      F
# 4689        2.25    0.0      F
# 4690        2.26    0.0      F
# 4691        2.27    0.0      F
# 4692        2.28    0.0      F
# 4693        2.29    0.0      F
# 4694        2.30    8.0      E
# 4695        2.31    0.0      F
# 4696        2.32    0.0      F
# 4697        2.33    0.0      F
# 4698        2.34    0.0      F
# 4699        2.35    0.0      F
# 4700        2.36    0.0      F
# 4701        2.37    0.0      F
# 4702        2.38    0.0      F
# 4703        2.39    0.0      F

# %%
fig, ax = plt.subplots(nrows=1,figsize=(20,15))
GEO='Prince Edward Island'
sizes2=DF1[(DF1['GEO']==GEO)&(DF1['REF_DATE']==2017)]['VALUE'][1:8]
ax.pie(sizes2,colors = ['b', 'y', 'k', 'tab:brown', 'g', 'goldenrod', 'r', 'm']
);
plt.savefig('PE2017.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(20,15))
GEO='Canada'

sizes1=DF1[(DF1['GEO']==GEO)&(DF1['REF_DATE']==2013)]['VALUE'][1:8]

sizes2=DF1[(DF1['GEO']==GEO)&(DF1['REF_DATE']==2017)]['VALUE'][1:8]

ax[0].pie(sizes1,colors = ['b', 'y', 'k', 'tab:brown', 'g', 'goldenrod', 'r', 'm']
);
ax[0].set_title(f"2013",fontdict={'fontsize': 26});
ax[1].pie(sizes2,colors = ['b', 'y', 'k', 'tab:brown', 'g', 'goldenrod', 'r', 'm']
);
ax[1].set_title(f"2017",fontdict={'fontsize': 26});


plt.savefig('Canada20132017.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(nrows=1, ncols=3,figsize=(20,15))
GEO='Canada'

sizes1=DF1[(DF1['GEO']==GEO)&(DF1['REF_DATE']==2013)]['VALUE'][1:9]
labels1=DF1[(DF1['GEO']==GEO)&(DF1['REF_DATE']==2013)]['Primary heating system and type of energy'][1:9]
labels1=labels1[sizes1!=0]
sizes1=sizes1[sizes1!=0]

sizes2=DF1[(DF1['GEO']==GEO)&(DF1['REF_DATE']==2015)]['VALUE'][1:9]
labels2=DF1[(DF1['GEO']==GEO)&(DF1['REF_DATE']==2015)]['Primary heating system and type of energy'][1:9]
labels2=labels2[sizes2!=0]
sizes2=sizes2[sizes2!=0]

sizes3=DF1[(DF1['GEO']==GEO)&(DF1['REF_DATE']==2017)]['VALUE'][1:9]
labels3=DF1[(DF1['GEO']==GEO)&(DF1['REF_DATE']==2017)]['Primary heating system and type of energy'][1:9]
labels3=labels3[sizes3!=0]
sizes3=sizes3[sizes3!=0]

ax[0].pie(sizes1,labels=labels1);
ax[0].set_title(f"{GEO} 2013");
ax[1].pie(sizes2,labels=labels2);
ax[1].set_title(f"{GEO} 2015");
ax[2].pie(sizes3,labels=labels3);
ax[2].set_title(f"{GEO} 2017");

# %%
fig, ax = plt.subplots(figsize=(20,10))
GEO='Canada'
labels=DF1[(DF1['GEO']==GEO)&(DF1['REF_DATE']==2013)]['Primary heating system and type of energy'][1:9]
sizes1=DF1[(DF1['GEO']==GEO)&(DF1['REF_DATE']==2013)]['VALUE'][1:9].astype(int)
sizes2=DF1[(DF1['GEO']==GEO)&(DF1['REF_DATE']==2015)]['VALUE'][1:9].astype(int)
sizes3=DF1[(DF1['GEO']==GEO)&(DF1['REF_DATE']==2017)]['VALUE'][1:9].astype(int)

x = np.arange(len(labels))
width = 0.33  # the width of the bars

bar1=ax.bar(x-width/1.4,sizes1,width,label='2013');
bar2=ax.bar(x,sizes2,width,label='2015');
bar3=ax.bar(x+width/1.4,sizes3,width,label='2017');
ax.set_title(f"Primary heating systems ({GEO})")
ax.set_xticks(x);
ax.set_xticklabels(labels,rotation='vertical');
ax.legend();

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
        
autolabel(bar1)
autolabel(bar2)
autolabel(bar3)

# %%
fig, ax = plt.subplots(figsize=(20,10))
GEO='Canada'
labels=('2013','2015','2017')

sizes1=DF1[(DF1['VECTOR']==DF1[(DF1['GEO']==GEO)&(DF1['Primary heating system and type of energy']=='Electricity')]['VECTOR'].iloc[0])&(DF1['GEO']==GEO)]['VALUE'].astype(int)
sizes2=DF1[(DF1['VECTOR']==DF1[(DF1['GEO']==GEO)&(DF1['Primary heating system and type of energy']=='Natural gas')]['VECTOR'].iloc[0])&(DF1['GEO']==GEO)]['VALUE'].astype(int)
sizes3=DF1[(DF1['VECTOR']==DF1[(DF1['GEO']==GEO)&(DF1['Primary heating system and type of energy']=='Oil')]['VECTOR'].iloc[0])&(DF1['GEO']==GEO)]['VALUE'].astype(int)
sizes4=DF1[(DF1['VECTOR']==DF1[(DF1['GEO']==GEO)&(DF1['Primary heating system and type of energy']=='Wood or wood pellets')]['VECTOR'].iloc[0])&(DF1['GEO']==GEO)]['VALUE'].astype(int)
sizes5=DF1[(DF1['VECTOR']==DF1[(DF1['GEO']==GEO)&(DF1['Primary heating system and type of energy']=='Wood (excluding wood pellets)')]['VECTOR'].iloc[0])&(DF1['GEO']==GEO)]['VALUE'].astype(int)
sizes6=DF1[(DF1['VECTOR']==DF1[(DF1['GEO']==GEO)&(DF1['Primary heating system and type of energy']=='Wood pellets')]['VECTOR'].iloc[0])&(DF1['GEO']==GEO)]['VALUE'].astype(int)
sizes7=DF1[(DF1['VECTOR']==DF1[(DF1['GEO']==GEO)&(DF1['Primary heating system and type of energy']=='Propane')]['VECTOR'].iloc[0])&(DF1['GEO']==GEO)]['VALUE'].astype(int)
sizes8=DF1[(DF1['VECTOR']==DF1[(DF1['GEO']==GEO)&(DF1['Primary heating system and type of energy']=='Other fuel')]['VECTOR'].iloc[0])&(DF1['GEO']==GEO)]['VALUE'].astype(int)

x = np.arange(len(labels))
width = 0.1  # the width of the bars

bar1=ax.bar(x-0.35,sizes1,width,label='Electricity');
bar2=ax.bar(x-0.25,sizes2,width,label='Natural Gas');
bar3=ax.bar(x-0.15,sizes3,width,label='Oil');
bar4=ax.bar(x-0.05,sizes4,width,label='Wood or wood pellets');
bar5=ax.bar(x+0.05,sizes5,width,label='Wood (excluding wood pellets)');
bar6=ax.bar(x+0.15,sizes6,width,label='Wood pellets');
bar7=ax.bar(x+0.25,sizes7,width,label='Propane');
bar8=ax.bar(x+0.35,sizes8,width,label='Other fuel');

ax.set_title(f"Primary heating systems ({GEO})")
ax.set_xticks(x);
ax.set_xticklabels(labels,rotation='vertical');
ax.legend();

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
        
autolabel(bar1)
autolabel(bar2)
autolabel(bar3)
autolabel(bar4)
autolabel(bar5)
autolabel(bar6)
autolabel(bar7)
autolabel(bar8)
